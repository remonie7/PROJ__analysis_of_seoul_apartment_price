# %%
import pandas as pd

naver=pd.read_csv("naver_crawling.csv", index_col=0)
naver
# Out:
#          지역   종류                   매물명    공급면적    전용면적     매물가  현재층범주
# 0       성북구  아파트            성북외교관사택단지   220.24  201.95  230000      1
# 1       성북구  아파트            성북외교관사택단지   204.48  186.42  215000      1
# 2       성북구  아파트            성북외교관사택단지   204.48  186.42  210000      1
# 3       구로구  아파트                   성원    75.22   56.97   31000      1
# 4       성동구  아파트                   동아   104.18   95.83  130000      1
# 5       은평구  아파트       은평뉴타운우물골2지구7단지   105.05   84.69   68000      1
# 6       성북구  아파트          길음뉴타운8단지래미안    84.58   59.99   80000      1
# 7       성북구  아파트            정릉힐스테이트3차   110.22   84.97   60000      1
# 8       강동구  아파트              주공고층3단지   109.58   99.61  183000      1
# 9       강동구  아파트           한솔브리즈(594)   128.61  107.86   65000      1
# 10      중랑구  아파트                온세솔내음    93.28   69.69   35000      1
# 11      은평구  아파트      은평뉴타운구파발10단지어울림   168.18  134.90   80500      1
# ...
